# %%
import pandas as pd

# %%
data = pd.read_csv("V02.03-07.csv",
                   sep=";",
                   skiprows=[0, 1, 3, 4, 5, 7, 18, 33, 54, 61],
                   index_col=0,
                   usecols=[0, 1])

# %%
data
# Out:
#                                                     Tổng số
#
# Hà Nội                                               7328.4
# Vĩnh Phúc                                            1066.0
# Bắc Ninh                                             1178.6
# Quảng Ninh                                           1224.6
# Hải Dương                                            1785.8
# Hải Phòng                                            1980.8
# Hưng Yên                                             1170.2
# Thái Bình                                            1790.0
# Hà Nam                                                803.7
# Nam Ðịnh                                             1852.6
# Ninh Bình                                             953.1
# Hà Giang                                              816.1
# Cao Bằng                                              529.8
# Bắc Kạn                                               319.0
# Tuyên Quang                                           766.9
# ...

# %%
data.dropna()
# Out:
#                    Tổng số
#
# Hà Nội              7328.4
# Vĩnh Phúc           1066.0
# Bắc Ninh            1178.6
# Quảng Ninh          1224.6
# Hải Dương           1785.8
# Hải Phòng           1980.8
# Hưng Yên            1170.2
# Thái Bình           1790.0
# Hà Nam               803.7
# Nam Ðịnh            1852.6
# Ninh Bình            953.1
# Hà Giang             816.1
# Cao Bằng             529.8
# Bắc Kạn              319.0
# Tuyên Quang          766.9
# Lào Cai              684.3
# Yên Bái              800.1
# Thái Nguyên         1227.4
# Lạng Sơn             768.7
# Bắc Giang           1657.6
# Phú Thọ             1381.7
# Ðiện Biên            557.4
# Lai Châu             436.0
# Sơn La              1208.0
# Hoà Bình             831.3
# Thanh Hoá           3528.3
# Nghệ An             3105.5
# Hà Tĩnh             1266.7
# Quảng Bình           877.7
# Quảng Trị            623.5
# ...                    ...
# Bình Ðịnh           1524.6
# Phú Yên              899.4
# ...

# %%
ten_largest = data.nlargest(10, columns="Tổng số")

# %%
# %matplotlib inline

# %%
ten_largest.plot(kind='bar', title='10 thành phố đông dân nhất Việt Nam (2015)').set_ylabel('nghìn người')
# Out:
# Text(0,0.5,'nghìn người')
